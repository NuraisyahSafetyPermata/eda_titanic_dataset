# %% [markdown]
# # INSTRUCTIONS
# Investigasi sampel data titanic berikut dengan cara :
# 1. Cek secara head, tail, sample, info lalu observasi apa yang bisa anda peroleh ?
# 2. Lakukan Statistical Summary dengan mengekstrak informasi yang didapat dari observasi anda ?
# 3. Cek apakah ada duplikat dan bagaimana handlenya ?
# 4. Cek apakah ada missing value, berapa persentasenya jika ada, dan bagaimana cara handlenya ?

# %% [markdown]
# # SECTION 1: LOAD AND DATA CHECK

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %% [markdown]
# ## Load Data

# %%
# import data
df = pd.read_excel('titanic.xlsx')
print("Data Loaded Successfully")
# Out:
# Data Loaded Successfully

# %% [markdown]
# ## Preliminary

# %%
# showing top 5 rows of the data
df.head()
# Out:
#    survived                                             name     sex      age
# 0         1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1         1                   Allison, Master. Hudson Trevor    male   0.9167
# 2         0                     Allison, Miss. Helen Loraine  female   2.0000
# 3         0             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000

# %%
# showing bottom 5 rows of the data
df.tail()
# Out:
#      survived                                     name     sex   age
# 495         1  Mallet, Mrs. Albert (Antoinette Magnin)  female  24.0
# 496         0        Mangiavacchi, Mr. Serafino Emilio    male   NaN
# 497         0               Matthews, Mr. William John    male  30.0
# 498         0                Maybery, Mr. Frank Hubert    male  40.0
# 499         0                McCrae, Mr. Arthur Gordon    male  32.0

# %%
# showing 5 random sample rows of the data
df.sample(5)
# Out:
#      survived                                         name     sex   age
# 98          1  Douglas, Mrs. Walter Donald (Mahala Dutton)  female  48.0
# 421         0                  Giles, Mr. Frederick Edward    male  21.0
# 265         1                 Sloper, Mr. William Thompson    male  28.0
# 414         0                              Gale, Mr. Harry    male  38.0
# 174         0                      Kent, Mr. Edward Austin    male  58.0

# %%
# showing data informations
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  500 non-null    int64
#  1   name      500 non-null    object
#  2   sex       500 non-null    object
#  3   age       451 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 15.8+ KB

# %% [markdown]
# Observation:
#
# 1.   Data contains 4 columns with 500 rows
# 2.   `age` is the only column have missing values, will be handled later
# 3.   All dtypes seem OK (appropriate), given the corresponding column name

# %% [markdown]
# ## Statistical Summary

# %%
# showing all columns on dataframe
df.columns
# Out:
# Index(['survived', 'name', 'sex', 'age'], dtype='object')

# %% [markdown]
# ### Categorical

# %%
# group column names based on type of data
categoricals = ['name', 'sex']

numericals = ['survived', 'age']

# %%
# syntax describe method on categorical data
df[categoricals].describe()
# Out:
#                                   name   sex
# count                              500   500
# unique                             499     2
# top     Eustis, Miss. Elizabeth Mussey  male
# freq                                 2   288

# %% [markdown]
# Observations:
#
# 1.  `name` have 499 unique value, `sex` have 2 unique value (male & female).
# 2.   **"Eustis, Miss. Elizabeth Mussey"** is the most of name (2 rows), and **"male"** is the most of gender/sex (288 rows)

# %%
categoricals
# Out:
# ['name', 'sex']

# %%
# showing the precise value counts
for col in categoricals:
  print(f"==== Value counts of {col} column ====")
  print(df[col].value_counts(), '\n')
# Out:
# ==== Value counts of name column ====
# name
# Eustis, Miss. Elizabeth Mussey                                                        2
# Becker, Miss. Ruth Elizabeth                                                          1
# Becker, Miss. Marion Louise                                                           1
# Becker, Master. Richard F                                                             1
# Beauchamp, Mr. Henry James                                                            1
# Beane, Mrs. Edward (Ethel Clarke)                                                     1
# Beane, Mr. Edward                                                                     1
# Bateman, Rev. Robert James                                                            1
# Banfield, Mr. Frederick James                                                         1
# Ball, Mrs. (Ada E Hall)                                                               1
# ...

# %% [markdown]
# ### Numerical

# %%
# syntax numerical statistical summary
df[numericals].describe()
# Out:
#          survived         age
# count  500.000000  451.000000
# mean     0.540000   35.917775
# std      0.498897   14.766454
# min      0.000000    0.666700
# 25%      0.000000   24.000000
# 50%      1.000000   35.000000
# 75%      1.000000   47.000000
# max      1.000000   80.000000

# %% [markdown]
# Observation:
#
# 1. `survived` is a binary column with values 0 and 1; the mean is **0.54**, indicating **slightly more survivors than non-survivors**. Balance level is acceptable but slightly skewed toward survivors.
# 2. `age` has **missing values** (451 out of 500 entries).
# 3. The **mean (35.9)** and **median (35.0)** of `age` column are close, suggesting a **roughly symmetrical distribution**.
# 4. The **minimum (0.66)** and **maximum (80)** values make sense for human age, although the minimum may represent an infant.
# 5. Need to handle missing values and possibly group ages for further analysis.

# %%
# showing the precis value counts
for col in numericals:
  print(f"==== Value counts of {col} column ====")
  print(df[col].value_counts(), '\n')
# Out:
# ==== Value counts of survived column ====
# survived
# 1    270
# 0    230
# Name: count, dtype: int64
#
# ==== Value counts of age column ====
# age
# 24.0000    23
# 30.0000    20
# 36.0000    19
# 18.0000    14
# 42.0000    14
# 45.0000    14
# 35.0000    14
# 22.0000    12
# 28.0000    12
# 23.0000    11
# 21.0000    11
# 31.0000    11
# 48.0000    11
# 25.0000    11
# 29.0000    10
# 54.0000    10
# 50.0000    10
# 34.0000    10
# 47.0000    10
# 39.0000     9
# 27.0000     9
# 33.0000     8
# 49.0000     8
# 38.0000     8
# 19.0000     8
# 40.0000     8
# 55.0000     8
# 32.0000     7
# 60.0000     7
# 17.0000     7
# 26.0000     7
# 44.0000     6
# 52.0000     6
# 37.0000     6
# 58.0000     6
# 64.0000     5
# 46.0000     5
# 57.0000     5
# 51.0000     5
# 16.0000     4
# 53.0000     4
# 56.0000     4
# 43.0000     4
# 62.0000     4
# 61.0000     4
# 1.0000      3
# 8.0000      3
# 63.0000     3
# 41.0000     3
# 15.0000     2
# 71.0000     2
# 20.0000     2
# 65.0000     2
# ...

# %% [markdown]
# # SECTION 2: PRA-PROCESSING DATA

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### 1. Duplicate Handling

# %%
# showing total rows of data
len(df)
# Out:
# 500

# %%
# showing total duplicate rows of data
df.duplicated().value_counts()
# Out:
# False    499
# True       1
# Name: count, dtype: int64

# %% [markdown]
# Observations:
# Only 1 row out of 500 total rows of data is duplicate

# %%
len(df.drop_duplicates())
# Out:
# 499

# %%
# if the output of the code in this cell is not 1 then there are duplicates
len(df.drop_duplicates()) / len(df)
# Out:
# 0.998

# %%
list(df.columns)
# Out:
# ['survived', 'name', 'sex', 'age']

# %%
# step 1: Retrieve duplicate rows (including the original one)
duplicates = df[df.duplicated(keep=False)]
duplicates
# Out:
#      survived                            name     sex   age
# 104         1  Eustis, Miss. Elizabeth Mussey  female  54.0
# 349         1  Eustis, Miss. Elizabeth Mussey  female  54.0

# %%
duplicates.groupby(list(df.columns)).size()
# Out:
# survived  name                            sex     age
# 1         Eustis, Miss. Elizabeth Mussey  female  54.0    2
# dtype: int64

# %%
duplicates.groupby(list(df.columns)).size().reset_index(name='number of duplicate')
# Out:
#    survived                            name     sex   age  number of duplicate
# 0         1  Eustis, Miss. Elizabeth Mussey  female  54.0                    2

# %%
# step 2: count the frequency of occurrence of duplicate row
duplicate_counts = duplicates.groupby(list(df.columns)).size().reset_index(name='number of duplicate')

# step 3: sort by number of duplicate
sorted_duplicates = duplicate_counts.sort_values(by='number of duplicate', ascending=False)

# step 4: display the sorted duplicates
print("Duplicate rows have been sorted by number of occurrens:")
sorted_duplicates
# Out:
# Duplicate rows have been sorted by number of occurrens:
#    survived                            name     sex   age  number of duplicate
# 0         1  Eustis, Miss. Elizabeth Mussey  female  54.0                    2

# %% [markdown]
# In the code `(df[df.duplicated(keep=False)])`, you directly print the rows that have duplicates by using the duplicated method and passing the `keep=False` parameter. This prints all the rows that have duplicates without subtracting anything from the DataFrame.

# %%
# handling drop duplicate
df = df.drop_duplicates()

# %%
len(df.drop_duplicates()) / len(df)
# Out:
# 1.0

# %% [markdown]
# Duplicate handled

# %% [markdown]
# ### 2. Missing Value Handling

# %% [markdown]
# #### Identifying Missing Value

# %%
df.isna().sum()
# Out:
# survived     0
# name         0
# sex          0
# age         49
# dtype: int64

# %%
for col in df.columns:
  print(f"============ {col} =============")
  display(df[col].value_counts())
  print()
# Out:
# ============ survived =============
# survived
# 1    269
# 0    230
# Name: count, dtype: int64
# ============ name =============
# name
# McCrae, Mr. Arthur Gordon                                                             1
# Allen, Miss. Elisabeth Walton                                                         1
# Allison, Master. Hudson Trevor                                                        1
# Lehmann, Miss. Bertha                                                                 1
# Laroche, Mrs. Joseph (Juliette Marie Louise Lafargue)                                 1
# Laroche, Mr. Joseph Philippe Lemercier                                                1
# Laroche, Miss. Simonne Marie Anne Andree                                              1
# Laroche, Miss. Louise                                                                 1
# Lamb, Mr. John Joseph                                                                 1
# ...

# %%
total_rows = len(df)
total_rows
# Out:
# 499

# %%
df.columns
# Out:
# Index(['survived', 'name', 'sex', 'age'], dtype='object')

# %%
# precentage version
total_rows = len(df)

# calculate and display the percentage of missing values in each column one by one
for col in df.columns:
    missing_count = df[col].isna().sum()
    missing_percentage = (missing_count / total_rows) * 100
    print(f"Column ' {col}' Has {missing_count} missing values ({missing_percentage}%)") # .2f means 2 decimal
# Out:
# Column ' survived' Has 0 missing values (0.0%)
# Column ' name' Has 0 missing values (0.0%)
# Column ' sex' Has 0 missing values (0.0%)
# Column ' age' Has 49 missing values (9.819639278557114%)

# %% [markdown]
# The percentage of missing values are below 20%, so we handle numerically with median, categorical with mode. But the categorical data type does not have missing values, namely `name` and `sex`.

# %% [markdown]
# #### Handling

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 499 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  499 non-null    int64
#  1   name      499 non-null    object
#  2   sex       499 non-null    object
#  3   age       450 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 19.5+ KB

# %%
df[['name', 'sex']].dtypes
# Out:
# name    object
# sex     object
# dtype: object

# %%
df[['name', 'sex']].mode().iloc[0]
# Out:
# name    Abelson, Mr. Samuel
# sex                    male
# Name: 0, dtype: object

# %%
df[['survived', 'age']].median()
# Out:
# survived     1.0
# age         35.0
# dtype: float64

# %%
# handling missing value for EDA, without splitting
for col in df.columns:
  if df[col].dtype == 'object':
    # if column dtype is object, fill with mode
    df[col].fillna(df[col].mode()[0], inplace=True)
  else:
    # if column dtype is object, fill with median
    df[col].fillna(df[col].median(), inplace=True)
# Out:
# <ipython-input-34-4f464f818bdd>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# <ipython-input-34-4f464f818bdd>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.isna().sum()
# Out:
# survived    0
# name        0
# sex         0
# age         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 499 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  499 non-null    int64
#  1   name      499 non-null    object
#  2   sex       499 non-null    object
#  3   age       499 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 19.5+ KB

# %% [markdown]
# Success removing NULL value

# %% [markdown]
# ### Inconsistent Data Handling

# %%
# checking unique value in column age
df['age'].unique()
# Out:
# array([29.    ,  0.9167,  2.    , 30.    , 25.    , 48.    , 63.    ,
#        39.    , 53.    , 71.    , 47.    , 18.    , 24.    , 26.    ,
#        80.    , 35.    , 50.    , 32.    , 36.    , 37.    , 42.    ,
#        19.    , 28.    , 45.    , 40.    , 58.    , 22.    , 41.    ,
#        44.    , 59.    , 60.    , 33.    , 17.    , 11.    , 14.    ,
#        49.    , 76.    , 46.    , 27.    , 64.    , 55.    , 70.    ,
#        38.    , 51.    , 31.    ,  4.    , 54.    , 23.    , 43.    ,
#        52.    , 16.    , 32.5   , 21.    , 15.    , 65.    , 28.5   ,
#        45.5   , 56.    , 13.    , 61.    , 34.    ,  6.    , 57.    ,
#        62.    , 67.    ,  1.    , 12.    , 20.    ,  0.8333,  8.    ,
#         0.6667,  7.    ,  3.    ])

# %% [markdown]
# Based on the output above, there are some inconsistent data in column age, such as 45.5, 0.6, 0.9, 32.5, 0.8, 28.5

# %%
# rounds age to the nearest whole
df['age'] = df['age'].round().astype(int)

# output
df['age'].unique()
# Out:
# array([29,  1,  2, 30, 25, 48, 63, 39, 53, 71, 47, 18, 24, 26, 80, 35, 50,
#        32, 36, 37, 42, 19, 28, 45, 40, 58, 22, 41, 44, 59, 60, 33, 17, 11,
#        14, 49, 76, 46, 27, 64, 55, 70, 38, 51, 31,  4, 54, 23, 43, 52, 16,
#        21, 15, 65, 56, 13, 61, 34,  6, 57, 62, 67, 12, 20,  8,  7,  3])

# %% [markdown]
# # SECTION 3: Exploratory Data Analysis

# %% [markdown]
# ## Sex Distribution

# %%
# showing the number of male and female
df['sex'].value_counts()
# Out:
# sex
# male      288
# female    211
# Name: count, dtype: int64

# %%
# visualize distribution
sns.countplot(data=df, x='sex')
plt.title('Sex Distribution')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Age Distribution

# %%
# showing the number of each age
df['age'].value_counts()
# Out:
# age
# 35    63
# 24    23
# 30    20
# 36    19
# 18    14
# 45    14
# 42    14
# 28    13
# 22    12
# 48    11
# 25    11
# 31    11
# 21    11
# 23    11
# 29    10
# 34    10
# 47    10
# 50    10
# 39     9
# 54     9
# 27     9
# 49     8
# 38     8
# 33     8
# 19     8
# 32     8
# 55     8
# 40     8
# 60     7
# 26     7
# 17     7
# 44     6
# 1      6
# 58     6
# 37     6
# 52     6
# 46     6
# 64     5
# 51     5
# 57     5
# 62     4
# 16     4
# 53     4
# 61     4
# 56     4
# 43     4
# 41     3
# 8      3
# 63     3
# 20     2
# 71     2
# 15     2
# 6      2
# 4      2
# 65     2
# 2      1
# 11     1
# 59     1
# 80     1
# 14     1
# 70     1
# 76     1
# 13     1
# 12     1
# 67     1
# 7      1
# 3      1
# Name: count, dtype: int64

# %% [markdown]
# Due to many unique age on data, i will categorize the age in to age groups, as follows:
# 1. Infants and Toddlers: < 5 years
# 2. Children: 5-9 years
# 3. Teenagers: 10-19 years
# 4. Adults: 20-59 years
# 5. Elderly: > 60 years

# %%
# categorizing age into age groups
def age_category(age):
    if age < 5:
        return 'Infants and Toddlers'
    elif 5 <= age <= 9:
        return 'Children'
    elif 10 <= age <= 19:
        return 'Teenagers'
    elif 20 <= age <= 59:
        return 'Adults'
    else:
        return 'Elderly'

df['age_group'] = df['age'].apply(age_category)
df[['age','age_group']].head()
# Out:
#    age             age_group
# 0   29                Adults
# 1    1  Infants and Toddlers
# 2    2  Infants and Toddlers
# 3   30                Adults
# 4   25                Adults

# %%
df['age_group'].value_counts()
# Out:
# age_group
# Adults                  413
# Teenagers                39
# Elderly                  31
# Infants and Toddlers     10
# Children                  6
# Name: count, dtype: int64

# %%
# visualize distribution
order = ['Infants and Toddlers', 'Children', 'Teenagers', 'Adults', 'Elderly']
sns.countplot(data=df, x='age_group', order=order)
plt.title('Age Distribution')
plt.xlabel('Age Category')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Age Category Distribution by Sex

# %%
order = ['Infants and Toddlers', 'Children', 'Teenagers', 'Adults', 'Elderly']
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df, x='age_group', hue='sex', order=order)
plt.title('Age Category Distribution by Sex')
plt.xlabel('Age Category')
plt.ylabel('Count')
plt.legend(title='Sex')

# Menambahkan label jumlah di atas bar
for container in ax.containers:
    ax.bar_label(container, fmt='%d', label_type='edge', padding=2)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Survival Rate

# %%
# calculate the total number of survivors and non-survivors
survival_counts = df['survived'].value_counts()
survival_counts
# Out:
# survived
# 1    269
# 0    230
# Name: count, dtype: int64

# %%
# visualize
plt.figure(figsize=(4,4))
plt.pie(survival_counts, labels=['Not Survived', 'Survived'], autopct='%1.1f%%', startangle=90)
plt.title('Overall Survival Proportion')
plt.show()

# %%
survival_count_by_sex = df.groupby(['sex', 'survived']).size().reset_index(name='count')
survival_count_by_sex
# Out:
#       sex  survived  count
# 0  female         0     15
# 1  female         1    196
# 2    male         0    215
# 3    male         1     73

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df, x='sex', hue='survived')
plt.title('Survival Count by Sex')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.legend(title='Survived', labels=['No', 'Yes'])  # 0 = not survived, 1 = survived
plt.show()

# %% [markdown]
# ## Age and Sex vs Survived

# %%
# encode sex category into numeric
df['sex_encoded'] = df['sex_numeric'] = df['sex'].map({'male': 0, 'female': 1})
df[['sex', 'sex_encoded']]
# Out:
#         sex  sex_encoded
# 0    female            1
# 1      male            0
# 2    female            1
# 3      male            0
# 4    female            1
# 5      male            0
# 6    female            1
# 7      male            0
# 8    female            1
# 9      male            0
# 10     male            0
# 11   female            1
# 12   female            1
# 13   female            1
# 14     male            0
# 15     male            0
# 16     male            0
# 17   female            1
# 18   female            1
# 19     male            0
# 20     male            0
# 21   female            1
# 22     male            0
# 23   female            1
# 24   female            1
# 25     male            0
# 26     male            0
# 27   female            1
# 28   female            1
# 29     male            0
# 30     male            0
# 31     male            0
# 32   female            1
# 33   female            1
# 34     male            0
# 35   female            1
# ...

# %%
# calculate the corelation matrix
correlation = df[['age', 'sex_encoded', 'survived']].corr()
correlation
# Out:
#                   age  sex_encoded  survived
# age          1.000000    -0.090120 -0.139254
# sex_encoded -0.090120     1.000000  0.669395
# survived    -0.139254     0.669395  1.000000

# %% [markdown]
# Observation:
# 1. Correlation between age and survived: `-0.136`
# This correlation shows that in general, there is no strong relationship between age and the likelihood of surviving. The slightly negative correlation indicates that older people are slightly less likely to survive, although the effect is very weak.
#
# 2. Correlation between sex_encoded and survived: `0.670`
# This relatively high positive correlation indicates that gender (in this case, female) has a significant impact on the likelihood of survival.

# %%
# visualize the correlation matrix using heatmap
plt.figure(figsize=(6,4))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f', vmin=-1, vmax=1)
plt.title('Correlation Matrix: Age, Sex, and Survival')
plt.show()

# %% [markdown]
# ## Age Distribution based on Survived

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='survived', y='age')
plt.title('Age Distribution Based on Survival Status')
plt.xlabel('Survived (0 = No, 1 = Yes)')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# # SECTION 4: Save Dataset to Excel

# %%
# !pip install openpyxl
df.to_excel('Titanic dataset (cleaned).xlsx', index=False)

# %%
# download file
from google.colab import files
files.download('Titanic dataset (cleaned).xlsx')
